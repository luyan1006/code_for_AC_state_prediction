# %%
# -*- coding: utf-8 -*-

import pandas as pd

df1=pd.read_csv(r'C:\luyan\paper_code\data\feature_data\trigger_temp.csv')

df2=pd.read_csv(r'C:\luyan\paper_code\data\feature_data\daily_duration.csv')

df3=pd.read_csv(r'C:\luyan\paper_code\data\feature_data\temp_in.csv')

df4=pd.read_csv(r'C:\luyan\paper_code\data\feature_data\setpoint_mean.csv')

df5=pd.read_csv(r'C:\luyan\paper_code\data\feature_data\setpoint_num.csv')

df6=pd.read_csv(r'C:\luyan\paper_code\data\daily.csv')[['id','ac_type']].drop_duplicates('id')

df=pd.merge(df1,df2,on='id')

df=pd.merge(df,df3,on='id')

df=pd.merge(df,df4,on='id')

df=pd.merge(df,df5,on='id')

df=pd.merge(df,df6,on='id')

df.head(5)
#df.to_csv(r'C:\luyan\paper_code\data\cluster_thermal_preference_data.csv',index=False)
# Out:
#              id  trigger_temp_mean  trigger_temp_median  trigger_temp_std  \
# 0  0007A88A4D8D          27.842029                27.80          1.502782
# 1  0007A88B9A54          26.964615                27.10          1.139686
# 2  0007A88B9C97          28.590000                28.75          2.076091
# 3  0007A88BA9B4          31.655556                31.55          0.931932
# 4  0007A88BCE80          30.160465                29.90          1.448010
#
#    trigger_temp_skew  trigger_temp_kurt  duration_mean  duration_median  \
# 0          -0.076451           0.755470      12.594447        13.058577
# 1          -0.498886           0.186714       5.702652         3.561026
# 2           0.267460          -0.598157       7.837327         7.230340
# 3           0.856593           0.032713       8.506129         6.108834
# 4           0.265062          -0.487133      11.632479        10.967803
#
#    duration_std  duration_skew  ...  set_point_weight_mean_median  \
# ...
