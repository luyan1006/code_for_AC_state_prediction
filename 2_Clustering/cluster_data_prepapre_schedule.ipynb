# %%
# -*- coding: utf-8 -*-

import pandas as pd

df1=pd.read_csv(r'C:\luyan\paper_code\data\24hour_percentage.csv')



df2=pd.read_csv(r'C:\luyan\paper_code\data\daily.csv')[['id','ac_type']].drop_duplicates('id')

df=pd.merge(df1,df2,on='id')

df.head(5)

#df.to_csv(r'C:\luyan\paper_code\data\cluster_schedule_preference_data.csv',index=False)
# Out:
#              id         0         1         2         3         4         5  \
# 0  0007A88A4D8D  0.058065  0.051613  0.059677  0.040323  0.041935  0.040323
# 1  0007A88B9A54  0.058140  0.037791  0.029070  0.020349  0.023256  0.020349
# 2  0007A88B9C97  0.059441  0.052448  0.055944  0.052448  0.055944  0.055944
# 3  0007A88BA9B4  0.067568  0.060811  0.054054  0.033784  0.027027  0.040541
# 4  0007A88BCE80  0.071283  0.069246  0.071283  0.052953  0.046843  0.036660
#
#           6         7         8  ...        15        16        17        18  \
# 0  0.035484  0.038710  0.040323  ...  0.027419  0.030645  0.032258  0.030645
# 1  0.023256  0.020349  0.017442  ...  0.020349  0.020349  0.023256  0.049419
# 2  0.055944  0.010490  0.003497  ...  0.020979  0.020979  0.024476  0.031469
# 3  0.040541  0.033784  0.054054  ...  0.060811  0.027027  0.013514  0.000000
# 4  0.036660  0.034623  0.034623  ...  0.028513  0.026477  0.026477  0.038697
#
# ...
